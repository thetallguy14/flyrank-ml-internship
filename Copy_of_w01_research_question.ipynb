# %% [markdown]
# <a href="https://colab.research.google.com/github/thetallguy14/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My Lane

#I chose the Search Intelligence lane. The goal is to identify content that is likely to decline in search performance so that it can be updated before traffic drops.
#This project is useful because websites often contain hundreds of pages, making manual monitoring difficult.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
#Can search performance metrics predict whether a webpage is likely to decline in organic search traffic?

#1.Which pages should be prioritized for optimization?
#Unit of analysis:
#One webpage.
Output:
A prediction indicating whether a page is likely to decline.
Action:
Update or improve pages predicted to decline.
Cost of a wrong recommendation:
False Positive:
Time is wasted updating a page that didn't need changes.
False Negative:
A declining page is missed, leading to reduced search traffic.


Why ML helps:
There are many interacting signals,
making manual rules difficult. Machine learning can learn patterns from
historical data and prioritize pages more effectively.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
## Quick Look at the Data

The starter dataset contains **30,000 webpages** and **44 features**.
The distribution of search trends is:
- Down: **16,262**
- Stable: **5,962**
- Up: **4,388**
- New: **2,236**
- Flat: **1,152**
The average click-through rate (CTR) is **0.511**, the average
 search position is **16.34**, and the average content age is **256 days**.

These statistics show that the dataset contains
substantial variation in search performance, making it suitable for
investigating whether machine learning can support decisions about which pages should be reviewed first.
# Out:
#   File "/tmp/ipykernel_4182/2034494738.py", line 3
#     The starter dataset contains **30,000 webpages** and **44 features**.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
## Careful Words

This project will identify observed patterns between
search metrics and trend direction using the available dataset.

The results should be interpreted as decision
support rather than proof of why a webpage's trend changes.

This project does not predict Google's ranking algorithm or establish causal relationships. Instead, it aims to
 provide evidence-based recommendations
 that can help prioritize pages for further review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
# !git clone https://github.com/thetallguy14/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
import os

print(os.listdir("/content/flyrank-ml-internship/data/raw"))
# Out:
# ['content_refresh_anonymized.csv']

# %%
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print(df.head())
print(df.columns.tolist())
print("Dataset Shape:", df.shape)

print("\nSummary Statistics:")
print(df.describe())

print("\nColumn Names:")
print(df.columns.tolist())
if "is_declining_label" in df.columns:
    print("\nDeclining Labels:")
    print(df["is_declining_label"].value_counts())

if "avg_position" in df.columns:
    print("\nAverage Position:", df["avg_position"].mean())

if "ctr" in df.columns:
    print("\nAverage CTR:", df["ctr"].mean())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...
